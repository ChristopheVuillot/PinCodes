# %%
import pyzx as zx

# %%
# circuit = zx.Circuit.from_qasm_file('circuit9CCZs.qasm')
circuit6 = zx.Circuit.from_qasm_file('circuit9CCZ6.qasm')

# %%
print(circuit6.stats())
# Out:
# Circuit circuit9CCZ6.qasm on 9 qubits with 6 gates.
#         42 is the T-count
#         0 Cliffords among which
#         0 2-qubit gates and 0 Hadamard gates.
# There are 6 gates of a different type

# %%
zx.draw(circuit6, figsize=(21,5))

# %%
graph = circuit6.to_graph()

# %%
zx.simplify.full_reduce(graph, quiet=False)
graph.normalise()
zx.draw(graph)
# Out:
# spider_simp: 15. 12. 7. 5. 2.  5 iterations
# id_simp: 6. 4.  2 iterations
# spider_simp: 2.  1 iterations
# lcomp_simp: 1. 1.  2 iterations
# pivot_gadget_simp: 16. 5. 3. 1.  4 iterations
# id_simp: 9.  1 iterations
# spider_simp: 4. 1.  2 iterations

# %%
zx.simplify.pivot_boundary_simp(graph, quiet=False)
graph.normalise()
zx.draw(graph)

# %%
zx.simplify.interior_clifford_simp(graph)
graph.normalise()
zx.draw(graph)
# Out:
# id_simp: 8.  1 iterations

# %%
zx.tcount(graph)
# Out:
# 24
